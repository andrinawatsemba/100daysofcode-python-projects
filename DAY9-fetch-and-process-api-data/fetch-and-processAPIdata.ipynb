# %%
pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\andrina\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.3)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Installing collected packages: urllib3, idna, certifi, requests
#
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------- ----------------------------- 1/4 [idna]
#    ---------- ----------------------------- 1/4 [idna]
#    ------------------------------ --------- 3/4 [requests]
#    ------------------------------ --------- 3/4 [requests]
#    ------------------------------ --------- 3/4 [requests]
#    ---------------------------------------- 4/4 [requests]
#
# Successfully installed certifi-2025.8.3 idna-3.10 requests-2.32.5 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json

# API endpoint using Example: Public API for Random Users
url = "https://randomuser.me/api/?results=5"

# Fetch data from API
response = requests.get(url)

# Checking if request was successful
if response.status_code == 200:
    data = response.json()
    print("API Data Fetched Successfully!\n")

    # Print fetched data
    print(json.dumps(data, indent=4))

    #Extract only names and emails
    users = []
    for user in data['results']:
        users.append({
            "name": f"{user['name']['first']} {user['name']['last']}",
            "email": user['email']
        })

# Save processed data to JSON
    with open("users.json", "w") as f:
        json.dump(users, f, indent=4)

    print("\nProcessed user data saved to users.json")

else:
    print(f"Error: Unable to fetch data (Status Code: {response.status_code})")
# Out:
# API Data Fetched Successfully!
#
# {
#     "results": [
#         {
#             "gender": "male",
#             "name": {
#                 "title": "Mr",
#                 "first": "Onisiy",
#                 "last": "Shostackiy"
#             },
#             "location": {
#                 "street": {
#                     "number": 1290,
#                     "name": "Rosiyskiy provulok"
#                 },
#                 "city": "Nosivka",
#                 "state": "Volinska",
#                 "country": "Ukraine",
#                 "postcode": 49370,
#                 "coordinates": {
#                     "latitude": "76.1931",
#                     "longitude": "-82.3973"
#                 },
#                 "timezone": {
#                     "offset": "-12:00",
#                     "description": "Eniwetok, Kwajalein"
#                 }
#             },
#             "email": "onisiy.shostackiy@example.com",
#             "login": {
#                 "uuid": "0f02c916-562d-44ff-b68e-325d493d8bdf",
#                 "username": "orangeswan313",
#                 "password": "hamburg",
#                 "salt": "tzj3r07E",
#                 "md5": "1ca1d11ef2d9e3b3bc0c53d67b4f2d43",
#                 "sha1": "f0edd2c5173278508b8ad359e2a1adbd637f5fde",
#                 "sha256": "805d748d5b9b679cb5a092837f7b463aefc022df1677959e7a2181c2fad5acc4"
#             },
#             "dob": {
#                 "date": "1952-06-20T23:52:49.256Z",
#                 "age": 73
#             },
#             "registered": {
#                 "date": "2009-07-16T06:46:58.441Z",
#                 "age": 16
#             },
#             "phone": "(067) P28-5789",
#             "cell": "(099) L45-4538",
#             "id": {
#                 "name": "",
#                 "value": null
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/men/83.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/men/83.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/men/83.jpg"
#             },
#             "nat": "UA"
#         },
#         {
#             "gender": "female",
#             "name": {
#                 "title": "Mrs",
#                 "first": "Denise",
#                 "last": "Obrien"
#             },
#             "location": {
#                 "street": {
#                     "number": 6380,
#                     "name": "Timber Wolf Trail"
#                 },
#                 "city": "Yakima",
#                 "state": "Montana",
#                 "country": "United States",
#                 "postcode": 37044,
#                 "coordinates": {
#                     "latitude": "69.8288",
#                     "longitude": "-16.6836"
#                 },
#                 "timezone": {
#                     "offset": "-3:00",
#                     "description": "Brazil, Buenos Aires, Georgetown"
#                 }
#             },
#             "email": "denise.obrien@example.com",
#             "login": {
#                 "uuid": "78685dfb-4a55-4adf-8474-65100d4a463e",
#                 "username": "purplefish484",
#                 "password": "dogbone",
#                 "salt": "DrzxdcaY",
#                 "md5": "48b44e1479e56998baf3c5a449d16e9a",
#                 "sha1": "7b7cc17978aecbc5730f93d9e6a0409dd28263fe",
#                 "sha256": "3c6dbcabbb941c48048a41700fdacaef2ee4ef32a39a2db26a95ca77a50caa0f"
#             },
#             "dob": {
#                 "date": "1955-10-02T00:02:03.834Z",
#                 "age": 69
#             },
#             "registered": {
#                 "date": "2020-10-15T06:52:59.348Z",
#                 "age": 4
#             },
#             "phone": "(954) 672-5205",
#             "cell": "(760) 817-9773",
#             "id": {
#                 "name": "SSN",
#                 "value": "168-42-0266"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/women/77.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/women/77.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/women/77.jpg"
#             },
#             "nat": "US"
#         },
#         {
#             "gender": "female",
#             "name": {
#                 "title": "Ms",
#                 "first": "Irmelin",
#                 "last": "Welde"
#             },
#             "location": {
#                 "street": {
#                     "number": 3338,
#                     "name": "Merkurveien"
#                 },
#                 "city": "Burfjord",
#                 "state": "Troms - Romsa",
#                 "country": "Norway",
#                 "postcode": "1661",
#                 "coordinates": {
#                     "latitude": "54.5008",
#                     "longitude": "151.3249"
#                 },
#                 "timezone": {
#                     "offset": "+7:00",
#                     "description": "Bangkok, Hanoi, Jakarta"
#                 }
#             },
#             "email": "irmelin.welde@example.com",
#             "login": {
#                 "uuid": "978b3841-8ba0-4d2b-bbc6-29d6413aab96",
#                 "username": "purplemeercat565",
#                 "password": "qwertyuiop",
#                 "salt": "OLQwGuib",
#                 "md5": "1ae67e6552b1460d98361b62e833ef51",
#                 "sha1": "9fea9e4f6b9a955dd35201dd825104382e8744c4",
#                 "sha256": "ceacb26a6175f18eea52c9698a47edb964fe7ef0db166423cee9a01663be236a"
#             },
#             "dob": {
#                 "date": "1980-03-13T23:07:10.199Z",
#                 "age": 45
#             },
#             "registered": {
#                 "date": "2004-10-29T20:05:42.755Z",
#                 "age": 20
#             },
#             "phone": "81882581",
#             "cell": "44207894",
#             "id": {
#                 "name": "FN",
#                 "value": "13038001897"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/women/40.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/women/40.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/women/40.jpg"
#             },
#             "nat": "NO"
#         },
#         {
#             "gender": "male",
#             "name": {
#                 "title": "Mr",
#                 "first": "Alfred",
#                 "last": "Barnett"
#             },
#             "location": {
#                 "street": {
#                     "number": 3479,
#                     "name": "Queens Road"
#                 },
#                 "city": "Derby",
#                 "state": "Dumfries and Galloway",
#                 "country": "United Kingdom",
#                 "postcode": "H4V 2XF",
#                 "coordinates": {
#                     "latitude": "79.1561",
#                     "longitude": "108.1333"
#                 },
#                 "timezone": {
#                     "offset": "-3:00",
#                     "description": "Brazil, Buenos Aires, Georgetown"
#                 }
#             },
#             "email": "alfred.barnett@example.com",
#             "login": {
#                 "uuid": "d581d0a9-b585-420b-a98a-26e2de38d337",
#                 "username": "purplebutterfly628",
#                 "password": "wannabe",
#                 "salt": "tkJjaaWb",
#                 "md5": "0a663ab636c353a2f5d9474acaca8529",
#                 "sha1": "7465fecd29ba1bb13e36685903c4a418c0894a58",
#                 "sha256": "2ff46a9abd77a9cf3f140f4c5357825305a55945d3db159e05da1712b7348a5c"
#             },
#             "dob": {
#                 "date": "1986-05-03T07:59:30.941Z",
#                 "age": 39
#             },
#             "registered": {
#                 "date": "2019-12-20T14:44:03.927Z",
#                 "age": 5
#             },
#             "phone": "016977 98311",
#             "cell": "07370 985601",
#             "id": {
#                 "name": "NINO",
#                 "value": "ZM 30 91 89 L"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/men/20.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/men/20.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/men/20.jpg"
#             },
#             "nat": "GB"
#         },
#         {
#             "gender": "female",
#             "name": {
#                 "title": "Ms",
#                 "first": "Chandenie",
#                 "last": "Botermans"
#             },
#             "location": {
#                 "street": {
#                     "number": 6534,
#                     "name": "Eisingarak"
#                 },
#                 "city": "Westhem",
#                 "state": "Flevoland",
#                 "country": "Netherlands",
#                 "postcode": "8259 PW",
#                 "coordinates": {
#                     "latitude": "-52.2938",
#                     "longitude": "-161.1292"
#                 },
#                 "timezone": {
#                     "offset": "+9:00",
#                     "description": "Tokyo, Seoul, Osaka, Sapporo, Yakutsk"
#                 }
#             },
#             "email": "chandenie.botermans@example.com",
#             "login": {
#                 "uuid": "bef6f274-0055-4a44-b529-200c0f919be3",
#                 "username": "purplegoose351",
#                 "password": "gene",
#                 "salt": "8ZdTaf6s",
#                 "md5": "80c6a4db7b179242b828860d7f1c0af0",
#                 "sha1": "90defc48d3e8ea05a5a8fd437fbd77bd0dec83f5",
#                 "sha256": "ca152349193b478b787a7d3dc71c0e91fa6192b316b919b94ad45948a2669eb4"
#             },
#             "dob": {
#                 "date": "1954-04-11T06:01:39.227Z",
#                 "age": 71
#             },
#             "registered": {
#                 "date": "2013-01-05T21:19:07.152Z",
#                 "age": 12
#             },
#             "phone": "(0933) 583315",
#             "cell": "(06) 77401848",
#             "id": {
#                 "name": "BSN",
#                 "value": "49409660"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/women/48.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/women/48.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/women/48.jpg"
#             },
#             "nat": "NL"
#         }
#     ],
#     "info": {
#         "seed": "d313b6e5a68baaea",
#         "results": 5,
#         "page": 1,
#         "version": "1.4"
#     }
# }
#
# Processed user data saved to users.json
