# %%
pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\andrina\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.3)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Installing collected packages: urllib3, idna, certifi, requests
#
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------------------------------------- 0/4 [urllib3]
#    ---------- ----------------------------- 1/4 [idna]
#    ---------- ----------------------------- 1/4 [idna]
#    ------------------------------ --------- 3/4 [requests]
#    ------------------------------ --------- 3/4 [requests]
#    ------------------------------ --------- 3/4 [requests]
#    ---------------------------------------- 4/4 [requests]
#
# Successfully installed certifi-2025.8.3 idna-3.10 requests-2.32.5 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json

# API endpoint (Example: Public API for Random Users)
url = "https://randomuser.me/api/?results=5"

# Fetch data from API
response = requests.get(url)

# Check if request was successful
if response.status_code == 200:
    data = response.json()
    print("API Data Fetched Successfully!\n")

    # Print fetched data
    print(json.dumps(data, indent=4))

    # Process data (Extract only names and emails)
    users = []
    for user in data['results']:
        users.append({
            "name": f"{user['name']['first']} {user['name']['last']}",
            "email": user['email']
        })

# Save processed data to JSON
    with open("users.json", "w") as f:
        json.dump(users, f, indent=4)

    print("\nProcessed user data saved to users.json")

else:
    print(f"Error: Unable to fetch data (Status Code: {response.status_code})")
# Out:
# API Data Fetched Successfully!
#
# {
#     "results": [
#         {
#             "gender": "female",
#             "name": {
#                 "title": "Mrs",
#                 "first": "Thea",
#                 "last": "Mortensen"
#             },
#             "location": {
#                 "street": {
#                     "number": 3359,
#                     "name": "Poppelv\u00e6nget"
#                 },
#                 "city": "Randers N\u00f8",
#                 "state": "Hovedstaden",
#                 "country": "Denmark",
#                 "postcode": 82858,
#                 "coordinates": {
#                     "latitude": "-46.3519",
#                     "longitude": "108.3890"
#                 },
#                 "timezone": {
#                     "offset": "+11:00",
#                     "description": "Magadan, Solomon Islands, New Caledonia"
#                 }
#             },
#             "email": "thea.mortensen@example.com",
#             "login": {
#                 "uuid": "f8af5aa5-c3e9-40b9-b28d-c8cc461b233f",
#                 "username": "ticklishrabbit570",
#                 "password": "laddie",
#                 "salt": "p3KbSJpk",
#                 "md5": "e11b00d65ef97905ada993a823fe3c6b",
#                 "sha1": "b6990f45464afd1526405eeafaa00c8c1c239858",
#                 "sha256": "bd70fd3d6dd5774e0213371beec43292e4b2a8c04ad0eafa5816b9bf701c672a"
#             },
#             "dob": {
#                 "date": "1989-08-30T07:27:58.692Z",
#                 "age": 36
#             },
#             "registered": {
#                 "date": "2018-08-10T07:42:04.646Z",
#                 "age": 7
#             },
#             "phone": "41712290",
#             "cell": "30220627",
#             "id": {
#                 "name": "CPR",
#                 "value": "300889-2401"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/women/26.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/women/26.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/women/26.jpg"
#             },
#             "nat": "DK"
#         },
#         {
#             "gender": "female",
#             "name": {
#                 "title": "Miss",
#                 "first": "Emma",
#                 "last": "White"
#             },
#             "location": {
#                 "street": {
#                     "number": 9102,
#                     "name": "West Ave"
#                 },
#                 "city": "Victoria",
#                 "state": "Newfoundland and Labrador",
#                 "country": "Canada",
#                 "postcode": "S0S 9U6",
#                 "coordinates": {
#                     "latitude": "-84.9619",
#                     "longitude": "-70.0813"
#                 },
#                 "timezone": {
#                     "offset": "-4:00",
#                     "description": "Atlantic Time (Canada), Caracas, La Paz"
#                 }
#             },
#             "email": "emma.white@example.com",
#             "login": {
#                 "uuid": "1330a4c4-6021-4d6f-84ef-e5259a70530b",
#                 "username": "bluesnake403",
#                 "password": "pretzel",
#                 "salt": "uLQDbuoc",
#                 "md5": "6e26870f3d6e6b7727be259d17a88317",
#                 "sha1": "af01a3baeeb3b1640c7c32f565645dbc9d85c9e6",
#                 "sha256": "636153b24947720525555822c78a4ab858cb2c4042daefdd5571140283df0ac2"
#             },
#             "dob": {
#                 "date": "1976-08-15T08:15:08.485Z",
#                 "age": 49
#             },
#             "registered": {
#                 "date": "2004-01-23T18:40:32.211Z",
#                 "age": 21
#             },
#             "phone": "B78 F63-2242",
#             "cell": "M76 L30-8226",
#             "id": {
#                 "name": "SIN",
#                 "value": "184539096"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/women/92.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/women/92.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/women/92.jpg"
#             },
#             "nat": "CA"
#         },
#         {
#             "gender": "female",
#             "name": {
#                 "title": "Mrs",
#                 "first": "Nevaeh",
#                 "last": "Phillips"
#             },
#             "location": {
#                 "street": {
#                     "number": 1507,
#                     "name": "James St"
#                 },
#                 "city": "Traralgon",
#                 "state": "South Australia",
#                 "country": "Australia",
#                 "postcode": 7849,
#                 "coordinates": {
#                     "latitude": "-54.5305",
#                     "longitude": "120.7204"
#                 },
#                 "timezone": {
#                     "offset": "-12:00",
#                     "description": "Eniwetok, Kwajalein"
#                 }
#             },
#             "email": "nevaeh.phillips@example.com",
#             "login": {
#                 "uuid": "591f0be3-9443-4647-8965-0e33a804fd8a",
#                 "username": "blackladybug179",
#                 "password": "beckham",
#                 "salt": "D6zCVrL1",
#                 "md5": "878ba498771301e88fffeb487db897b1",
#                 "sha1": "5e8bb698461681d1c591bc71d507ac0e729a7bd3",
#                 "sha256": "1a985cf1783da27c63ed4a254215681565dca348acdbe23b28c7b950801282b9"
#             },
#             "dob": {
#                 "date": "1958-05-04T14:07:57.519Z",
#                 "age": 67
#             },
#             "registered": {
#                 "date": "2018-01-16T15:38:49.411Z",
#                 "age": 7
#             },
#             "phone": "05-2098-9383",
#             "cell": "0492-586-667",
#             "id": {
#                 "name": "TFN",
#                 "value": "910487872"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/women/32.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/women/32.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/women/32.jpg"
#             },
#             "nat": "AU"
#         },
#         {
#             "gender": "male",
#             "name": {
#                 "title": "Mr",
#                 "first": "Earl",
#                 "last": "Morris"
#             },
#             "location": {
#                 "street": {
#                     "number": 19,
#                     "name": "Mockingbird Ln"
#                 },
#                 "city": "Bendigo",
#                 "state": "New South Wales",
#                 "country": "Australia",
#                 "postcode": 3917,
#                 "coordinates": {
#                     "latitude": "-11.4019",
#                     "longitude": "101.1059"
#                 },
#                 "timezone": {
#                     "offset": "-12:00",
#                     "description": "Eniwetok, Kwajalein"
#                 }
#             },
#             "email": "earl.morris@example.com",
#             "login": {
#                 "uuid": "3646ac26-b1d7-486e-9e9b-1beca0fbba02",
#                 "username": "angryrabbit653",
#                 "password": "3006",
#                 "salt": "MujjZcTO",
#                 "md5": "a10335cb88cc962042885d81837e1019",
#                 "sha1": "f4654b2b299bb13752be24336b870fddcb36707d",
#                 "sha256": "bfece9d409120f5dd9981808520e55faa7c6ffcd7b84b8727c7a8ee503ba1265"
#             },
#             "dob": {
#                 "date": "1994-04-06T01:43:29.604Z",
#                 "age": 31
#             },
#             "registered": {
#                 "date": "2018-03-16T18:16:06.627Z",
#                 "age": 7
#             },
#             "phone": "05-9919-8423",
#             "cell": "0439-039-432",
#             "id": {
#                 "name": "TFN",
#                 "value": "833467857"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/men/41.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/men/41.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/men/41.jpg"
#             },
#             "nat": "AU"
#         },
#         {
#             "gender": "male",
#             "name": {
#                 "title": "Mr",
#                 "first": "Vilho",
#                 "last": "Leppo"
#             },
#             "location": {
#                 "street": {
#                     "number": 1069,
#                     "name": "Pispalan Valtatie"
#                 },
#                 "city": "Parikkala",
#                 "state": "\u00c5land",
#                 "country": "Finland",
#                 "postcode": 14142,
#                 "coordinates": {
#                     "latitude": "-15.5315",
#                     "longitude": "136.6253"
#                 },
#                 "timezone": {
#                     "offset": "+9:30",
#                     "description": "Adelaide, Darwin"
#                 }
#             },
#             "email": "vilho.leppo@example.com",
#             "login": {
#                 "uuid": "857e67c4-9d22-4713-8584-0fde5d6e49da",
#                 "username": "heavyzebra766",
#                 "password": "cannabis",
#                 "salt": "hYiV7kLl",
#                 "md5": "d1c022c09ba7925a94b0c3b24210bcb3",
#                 "sha1": "3cd4fc3ed38f0bded7d74f3ab5ad44b68a1331b3",
#                 "sha256": "9645f42c60cd8d6bcf2ec64ac484bd7b1044a00ab4e80e937b3f666ea89b565e"
#             },
#             "dob": {
#                 "date": "1954-04-26T23:01:09.835Z",
#                 "age": 71
#             },
#             "registered": {
#                 "date": "2007-06-20T03:03:10.612Z",
#                 "age": 18
#             },
#             "phone": "02-402-478",
#             "cell": "043-829-66-17",
#             "id": {
#                 "name": "HETU",
#                 "value": "NaNNA863undefined"
#             },
#             "picture": {
#                 "large": "https://randomuser.me/api/portraits/men/13.jpg",
#                 "medium": "https://randomuser.me/api/portraits/med/men/13.jpg",
#                 "thumbnail": "https://randomuser.me/api/portraits/thumb/men/13.jpg"
#             },
#             "nat": "FI"
#         }
#     ],
#     "info": {
#         "seed": "cf2c61768a4672a3",
#         "results": 5,
#         "page": 1,
#         "version": "1.4"
#     }
# }
#
# Processed user data saved to users.json
